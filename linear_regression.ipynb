# %% [markdown]
# <a href="https://colab.research.google.com/github/Manishramachandran21/Regression-Model-/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import linear_model
data = pd.read_csv('/content/canada_per_capita_income.csv')
data
x = data[['year']]
y = data[['per capita income (US$)']]
model = linear_model.LinearRegression()
model.fit(x,y)
model.predict([[2020]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])
